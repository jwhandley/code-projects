# %%
from matplotlib import pyplot as plt
import numpy as np
from scipy import stats

x = np.linspace(100,150000,num=100)

x[0:5]
# Out:
# array([ 100.        , 1614.14141414, 3128.28282828, 4642.42424242,
#        6156.56565657])

# %%
plt.plot(x,stats.lognorm.pdf(x,s=0.5,scale=50000))

mean = np.exp(np.log(50000) + 0.25/2)
sd = np.sqrt((np.exp(0.25)-1)*np.exp(2*np.log(50000) + 0.25))
mode = np.exp(np.log(50000)-0.25)
median = 50000

#plt.axvline(mode,label='Mode',color='green')
plt.axvline(median,label='Median',color='k')
plt.axvline(mean,label='Mean')
plt.legend()

# %%
# Out:
# 38940.03915357025
