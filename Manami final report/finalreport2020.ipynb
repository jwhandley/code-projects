# %% [markdown]
# ## Final Report
#
# ### Yield Curve
#
# 1. Retrieve U.S. treasury bond yields data:
#
#   + 1-month treasury constant maturity rate
#   + 3-month treasury constant maturity rate
#   + 6-month treasury constant maturity rate
#   + 1-year treasury constant maturity rate
#   + 2-year treasury constant maturity rate
#   + 3-year treasury constant maturity rate
#   + 5-year treasury constant maturity rate
#   + 7-year treasury constant maturity rate
#   + 10-year treasury constant maturity rate
#
# from https://fred.stlouisfed.org
#
# The sample period is January 2015 - December 2019.
#
# 2. Draw a 3-D surface plot of U.S. treasury bond yields.
#
# ### Portfolio Selection
#
# 1. Download **49 Industry Portfolios** data from
#
#   http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/data_library.html
#
# 2. We treat each of 49 industry portfolios as an asset and consider an
# optimal portfolio selection problem with these 49 assets. Using the
# monthly returns data **from January 1990 to December 2009**, draw the
# efficient frontier for
#
#   + minimum variance portfolio problem
#   + minimum mean absolute deviation portfolio problem
#   + minimum semi-variance portfolio problem
#   + optimal expected shortfall portfolio problem
#
# with the short selling constraint.
#
# 3. Compute allocation weights of the following portfolios:
#
#   + equal-weight portfolio
#   + global minimum variance portfolio
#   + risk parity portfolio
#   + maximum diversification portfolio
#
# They are based on the covariance matrix estimated with the data **from January 1990 to December 2009**.
#
# 4. Compare the performance of the above portfolios in the buy-and-hold strategy **from January 2010 to December 2019**
#
# ### Factor Models
#
# 1. Download monthly Fama-French 5 factors data from
#
#   http://mba.tuck.dartmouth.edu/pages/faculty/ken.french/data_library.html
#
# The sample period is from January 2010 to December 2019.
#
# 2. For 49 industry portfolios, estimate the following factor models.
#
#   + CAPM
#   + Fama-French three-factor model
#   + Fama-French five-factor model
