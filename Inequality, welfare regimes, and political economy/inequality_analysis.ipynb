# %%
import pandas as pd
import numpy as np
from linearmodels import PanelOLS, FirstDifferenceOLS

cwed = pd.read_csv('cwed_gen.csv')
gini = pd.read_csv('swiid8_3_summary.csv')
etcr = pd.read_csv('etcreg.csv')

df = pd.merge(pd.merge(cwed,gini),etcr)
data = df.set_index(['country','year'])

data.head()
# Out:
#                 totgen  uegen  skgen  pgen  gini_disp  gini_disp_se  gini_mkt  \
# country   year
# Australia 1975    20.2    7.2    6.3   6.7       25.2           0.8      38.3
#           1976    21.0    7.5    6.6   6.8       25.7           1.1      38.6
#           1977    21.2    7.6    6.7   6.9       26.2           1.1      39.0
#           1978    21.2    7.6    6.6   7.1       26.6           1.1      39.3
#           1979    21.2    7.5    6.6   7.1       27.1           1.0      39.6
#
#                 gini_mkt_se  abs_red  abs_red_se  rel_red  rel_red_se  \
# country   year
# Australia 1975          1.5     13.1         1.7     34.2         2.3
#           1976          1.6     12.9         1.9     33.4         2.5
#           1977          1.5     12.8         1.9     32.8         2.4
#           1978          1.5     12.7         1.9     32.3         2.4
#           1979          1.4     12.5         1.7     31.6         2.2
#
#                   etcreg
# country   year
# Australia 1975  4.101191
#           1976  4.101191
#           1977  4.101191
#           1978  4.101191
#           1979  4.101191

# %%
fe = PanelOLS.from_formula('gini_disp ~ 1 + totgen + etcreg + EntityEffects + TimeEffects',data.dropna(subset=['gini_disp','totgen','etcreg']))
fe.fit()
# Out:
# C:\Users\jwhan\anaconda3\lib\site-packages\linearmodels\panel\data.py:98: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_categorical(s):
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              gini_disp   R-squared:                        0.1590
# Estimator:                   PanelOLS   R-squared (Between):              0.4301
# No. Observations:                 659   R-squared (Within):               0.3673
# Date:                Sun, Oct 11 2020   R-squared (Overall):              0.3926
# Time:                        17:17:02   Log-likelihood                   -1047.8
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      56.723
# Entities:                          22   P-value                           0.0000
# Avg Obs:                       29.955   Distribution:                   F(2,600)
# Min Obs:                       3.0000
# Max Obs:                       36.000   F-statistic (robust):             56.723
#                                         P-value                           0.0000
# Time periods:                      36   Distribution:                   F(2,600)
# Avg Obs:                       18.306
# Min Obs:                       9.0000
# Max Obs:                       22.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      38.241     0.9608     39.802     0.0000      36.354      40.128
# totgen        -0.2450     0.0262    -9.3626     0.0000     -0.2964     -0.1936
# etcreg        -0.5921     0.1456    -4.0661     0.0001     -0.8781     -0.3061
# ==============================================================================
#
# F-test for Poolability: 53.193
# P-value: 0.0000
# Distribution: F(56,600)
#
# Included effects: Entity, Time
# PanelEffectsResults, id: 0x245f93b76d0

# %%
mkt = PanelOLS.from_formula('gini_mkt ~  1 + etcreg + TimeEffects + EntityEffects',data.dropna(subset=['gini_mkt','etcreg']))
mkt.fit()
# Out:
# C:\Users\jwhan\anaconda3\lib\site-packages\linearmodels\panel\data.py:98: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if is_categorical(s):
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:               gini_mkt   R-squared:                        0.0672
# Estimator:                   PanelOLS   R-squared (Between):             -0.1206
# No. Observations:                 659   R-squared (Within):               0.5718
# Date:                Sun, Oct 11 2020   R-squared (Overall):              0.1529
# Time:                        17:17:13   Log-likelihood                   -1222.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      43.263
# Entities:                          22   P-value                           0.0000
# Avg Obs:                       29.955   Distribution:                   F(1,601)
# Min Obs:                       3.0000
# Max Obs:                       36.000   F-statistic (robust):             43.263
#                                         P-value                           0.0000
# Time periods:                      36   Distribution:                   F(1,601)
# Avg Obs:                       18.306
# Min Obs:                       9.0000
# Max Obs:                       22.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      49.756     0.7350     67.693     0.0000      48.312      51.199
# etcreg        -1.2405     0.1886    -6.5775     0.0000     -1.6108     -0.8701
# ==============================================================================
#
# F-test for Poolability: 47.712
# P-value: 0.0000
# Distribution: F(56,601)
#
# Included effects: Entity, Time
# PanelEffectsResults, id: 0x245f93ded30
